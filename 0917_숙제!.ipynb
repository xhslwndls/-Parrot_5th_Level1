# %%
#1. 0부터 15까지의 숫자가 차례대로 나열된,ndarray a를 만드세요

# %%
#2. a의 shape를 (4,4)로 바꾸고, 1부터 16까지의 값이 되도록 바꾸세요

# %%
#3. 0부터 24까지의 수가 임의로 배치된, (5,5)의 shape를 지닌 ndarray b를 만드세요

# %%
#4. b의 4행, 4열까지의 값과 a의 행렬 곱연산을 진행한 c를 만드세요

# %%
#5. 10보다 큰 c의 원소들의 값을 0으로 바꾸세요.

# %%
#6. np.linalg.inv()를 이용하여 다음 연립방정식의 해를 구하세요
#x+y-z=0, 2x-y+3z=9, x+2y+z=8

# %%
#7. 아래 그림을 참고, 한라산을 제외한 후 소주 별 '이름', '도수', '지역'으로 구성된 DataFrame aa를 만드세요

# %% [markdown]
# ![thumb-16244594666825_835x834 (1).jpg](data:image/jpeg;base64,...)

# %%
#8. aa의 열 중 '이름'을 aa의 index로 설정 후, index의 이름을 '메뉴'로 바꾸세요

# %%
#9. aa에 한라산에 대한 정보를 지닌 행을 추가하세요

# %%
#10. aa를 높은 가격이 위로 오도록 정렬한 bb를 만드세요

# %%
#10. bb의 하위 5개 항목을 보여주세요

# %%
#11. bb의 행들 중 충청도 지역에서 유통되는 소주인 경우를 보이세요 (loc, 조건문 이용)

# %%
#12. bb의 상위 4개 행에 대해 '도수'만을 열로 가진 DataFrame을 보이세요(iloc 이용)

# %%
#13. bb에서 참이슬을 제거하세요

# %%
#14. https://www.data.go.kr/ 등을 이용해 본인이 원하는 데이터를 다운받은 후, pandas의 read 기능을 이용해 불러오세요

# %%
#15. 불러온 데이터 중 결측치가 없는 열을 모두 표시하세요

# %%
#16. 불러온 데이터의 결측치를 가장 적합한 방법(정답은 없어요..)으로 제거하세요

# %%
#17. 즐거운 추석 보내세요:)
