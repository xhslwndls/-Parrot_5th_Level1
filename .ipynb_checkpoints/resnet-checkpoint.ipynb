# %%
import os
import datetime
import numpy

import tensorflow as tf

from tensorflow import keras
from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization, Activation
from tensorflow.keras.layers import AveragePooling2D, Input, Flatten
from tensorflow.keras import activations
from tensorflow.keras.regularizers import l2

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

import pydot
import IPython
from IPython.display import SVG
from tensorflow.keras.utils import model_to_dot, plot_model
from tensorflow.keras.callbacks import ModelCheckpoint

import cv2
#%%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x


def resnet_v1(inputs, filters, num_res_blocks, pool_size):

    x = resnet_layer(inputs=inputs,
                     num_filters=filters[0])

    # Instantiate the stack of residual units
    for stack, filters in enumerate(filters):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
 
    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=pool_size)(x)
    y = Flatten()(x)

    return y


def resnet_v2(inputs, filters, num_res_blocks, pool_size):

    x = resnet_layer(inputs=inputs,
                     num_filters=filters[0],
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage, filters in enumerate(filters):
        num_filters_in = filters
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=pool_size)(x)
    y = Flatten()(x)
    return y
#%%
def train_and_eval(model, x_train, y_train, x_test, y_test, filename, batch_size, epochs):
    
    checkpoint = ModelCheckpoint(filename, verbose=1, monitor='val_loss',save_best_only=True, mode='auto')
    
    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_data=(x_test, y_test),
                        callbacks=[checkpoint])    
    
    model.load_weights(filename)
    model.save(filename)
    
    fig = plt.figure(figsize=[30, 10])
    ax = fig.add_subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    ax.legend()
    ax.set_title('Training Performance')

    
    ax = fig.add_subplot(1, 3, 2)
    pred = model.predict(x_train);
    indexes = tf.argmax(pred, axis=1)
    cm = confusion_matrix(y_train, indexes)
    c = ConfusionMatrixDisplay(cm, display_labels=range(10))
    c.plot(ax = ax)    
    ax.set_title('Training')
    
    ax = fig.add_subplot(1, 3, 3)
    pred = model.predict(x_test);
    indexes = tf.argmax(pred, axis=1)
    cm = confusion_matrix(y_test, indexes)
    c = ConfusionMatrixDisplay(cm, display_labels=range(10))
    c.plot(ax = ax)    
    ax.set_title('Testing')
#%%
batch_size = 128
num_epochs = 100
#%%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

x_train = x_train.reshape(x_train.shape[0], 28, 28, 1).astype('float32') / 255.0
y_train = y_train.reshape(y_train.shape[0], 1)
x_test = x_test.reshape(x_test.shape[0], 28, 28, 1).astype('float32') / 255.0
y_test = y_test.reshape(y_test.shape[0], 1)


#%%
plt.imshow(x_train[0])
#%% Resnet v1
inputs = Input(shape=(28, 28, 1, ), name='img')
x = resnet_v1(inputs, [32, 64, 128], 2, 7)
output = Dense(10)(x)
model_cnn = keras.Model(inputs=inputs, outputs=output, name='large_resnet_v1')
model_cnn.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.RMSprop(),
              metrics=['accuracy'])
train_and_eval(model_cnn, x_train, y_train, x_test, y_test, 'resnet_v1_MNIST_big.h5', batch_size, num_epochs)
# Out:
# Epoch 1/100
# 469/469 [==============================] - 46s 40ms/step - loss: 0.3405 - accuracy: 0.9569 - val_loss: 0.2434 - val_accuracy: 0.9792
#
# Epoch 00001: val_loss improved from inf to 0.24342, saving model to resnet_v1_MNIST_big.h5
# Epoch 2/100
#   1/469 [..............................] - ETA: 15s - loss: 0.2288 - accuracy: 0.9766
# C:\Anaconda3\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 469/469 [==============================] - 17s 36ms/step - loss: 0.1879 - accuracy: 0.9859 - val_loss: 0.4266 - val_accuracy: 0.8996
#
# Epoch 00002: val_loss did not improve from 0.24342
# Epoch 3/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.1416 - accuracy: 0.9893 - val_loss: 1.0003 - val_accuracy: 0.7608
#
# Epoch 00003: val_loss did not improve from 0.24342
# Epoch 4/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.1173 - accuracy: 0.9894 - val_loss: 0.1304 - val_accuracy: 0.9811
#
# Epoch 00004: val_loss improved from 0.24342 to 0.13037, saving model to resnet_v1_MNIST_big.h5
# Epoch 5/100
# 469/469 [==============================] - 18s 37ms/step - loss: 0.1001 - accuracy: 0.9901 - val_loss: 0.1029 - val_accuracy: 0.9884
#
# Epoch 00005: val_loss improved from 0.13037 to 0.10292, saving model to resnet_v1_MNIST_big.h5
# Epoch 6/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0875 - accuracy: 0.9914 - val_loss: 0.1046 - val_accuracy: 0.9848
#
# Epoch 00006: val_loss did not improve from 0.10292
# Epoch 7/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0790 - accuracy: 0.9920 - val_loss: 0.2576 - val_accuracy: 0.9270
#
# Epoch 00007: val_loss did not improve from 0.10292
# Epoch 8/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0732 - accuracy: 0.9925 - val_loss: 0.1602 - val_accuracy: 0.9648
#
# Epoch 00008: val_loss did not improve from 0.10292
# Epoch 9/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0685 - accuracy: 0.9926 - val_loss: 0.1032 - val_accuracy: 0.9816
#
# Epoch 00009: val_loss did not improve from 0.10292
# Epoch 10/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0653 - accuracy: 0.9926 - val_loss: 0.1135 - val_accuracy: 0.9769
#
# Epoch 00010: val_loss did not improve from 0.10292
# Epoch 11/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0614 - accuracy: 0.9930 - val_loss: 0.0914 - val_accuracy: 0.9830
#
# Epoch 00011: val_loss improved from 0.10292 to 0.09142, saving model to resnet_v1_MNIST_big.h5
# Epoch 12/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0585 - accuracy: 0.9931 - val_loss: 0.1122 - val_accuracy: 0.9766
#
# Epoch 00012: val_loss did not improve from 0.09142
# Epoch 13/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0563 - accuracy: 0.9936 - val_loss: 0.0681 - val_accuracy: 0.9901
#
# Epoch 00013: val_loss improved from 0.09142 to 0.06811, saving model to resnet_v1_MNIST_big.h5
# Epoch 14/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0555 - accuracy: 0.9936 - val_loss: 0.0864 - val_accuracy: 0.9839
#
# Epoch 00014: val_loss did not improve from 0.06811
# Epoch 15/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0514 - accuracy: 0.9939 - val_loss: 0.0864 - val_accuracy: 0.9847
#
# Epoch 00015: val_loss did not improve from 0.06811
# Epoch 16/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0505 - accuracy: 0.9939 - val_loss: 0.0867 - val_accuracy: 0.9825
#
# Epoch 00016: val_loss did not improve from 0.06811
# Epoch 17/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0484 - accuracy: 0.9943 - val_loss: 0.0862 - val_accuracy: 0.9848
#
# Epoch 00017: val_loss did not improve from 0.06811
# Epoch 18/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0482 - accuracy: 0.9946 - val_loss: 0.0577 - val_accuracy: 0.9915
#
# Epoch 00018: val_loss improved from 0.06811 to 0.05770, saving model to resnet_v1_MNIST_big.h5
# Epoch 19/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0462 - accuracy: 0.9945 - val_loss: 0.0758 - val_accuracy: 0.9856
#
# Epoch 00019: val_loss did not improve from 0.05770
# Epoch 20/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0436 - accuracy: 0.9952 - val_loss: 0.2514 - val_accuracy: 0.9395
#
# Epoch 00020: val_loss did not improve from 0.05770
# Epoch 21/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0430 - accuracy: 0.9951 - val_loss: 0.1463 - val_accuracy: 0.9671
#
# Epoch 00021: val_loss did not improve from 0.05770
# Epoch 22/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0432 - accuracy: 0.9952 - val_loss: 0.1743 - val_accuracy: 0.9651
#
# Epoch 00022: val_loss did not improve from 0.05770
# Epoch 23/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0403 - accuracy: 0.9955 - val_loss: 0.0530 - val_accuracy: 0.9920
#
# Epoch 00023: val_loss improved from 0.05770 to 0.05297, saving model to resnet_v1_MNIST_big.h5
# Epoch 24/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0413 - accuracy: 0.9949 - val_loss: 0.0730 - val_accuracy: 0.9863
#
# Epoch 00024: val_loss did not improve from 0.05297
# Epoch 25/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0400 - accuracy: 0.9953 - val_loss: 0.0924 - val_accuracy: 0.9818
#
# Epoch 00025: val_loss did not improve from 0.05297
# Epoch 26/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0390 - accuracy: 0.9958 - val_loss: 0.0787 - val_accuracy: 0.9855
#
# Epoch 00026: val_loss did not improve from 0.05297
# Epoch 27/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0390 - accuracy: 0.9955 - val_loss: 0.0600 - val_accuracy: 0.9889
#
# Epoch 00027: val_loss did not improve from 0.05297
# Epoch 28/100
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0389 - accuracy: 0.9954 - val_loss: 0.1329 - val_accuracy: 0.9727
#
# Epoch 00028: val_loss did not improve from 0.05297
# Epoch 29/100
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0377 - accuracy: 0.9959 - val_loss: 0.0584 - val_accuracy: 0.9888
#
# Epoch 00029: val_loss did not improve from 0.05297
# Epoch 30/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0376 - accuracy: 0.9959 - val_loss: 0.0587 - val_accuracy: 0.9904
#
# Epoch 00030: val_loss did not improve from 0.05297
# Epoch 31/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0360 - accuracy: 0.9962 - val_loss: 0.0583 - val_accuracy: 0.9910
#
# Epoch 00031: val_loss did not improve from 0.05297
# Epoch 32/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0354 - accuracy: 0.9962 - val_loss: 0.0737 - val_accuracy: 0.9861
#
# Epoch 00032: val_loss did not improve from 0.05297
# Epoch 33/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0353 - accuracy: 0.9963 - val_loss: 0.1085 - val_accuracy: 0.9783
#
# Epoch 00033: val_loss did not improve from 0.05297
# Epoch 34/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0339 - accuracy: 0.9966 - val_loss: 0.0505 - val_accuracy: 0.9921
#
# Epoch 00034: val_loss improved from 0.05297 to 0.05050, saving model to resnet_v1_MNIST_big.h5
# Epoch 35/100
# 469/469 [==============================] - 20s 44ms/step - loss: 0.0345 - accuracy: 0.9964 - val_loss: 0.0823 - val_accuracy: 0.9851
#
# Epoch 00035: val_loss did not improve from 0.05050
# Epoch 36/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0327 - accuracy: 0.9965 - val_loss: 0.1409 - val_accuracy: 0.9737
#
# Epoch 00036: val_loss did not improve from 0.05050
# Epoch 37/100
# 469/469 [==============================] - 21s 45ms/step - loss: 0.0338 - accuracy: 0.9963 - val_loss: 0.0863 - val_accuracy: 0.9854
#
# Epoch 00037: val_loss did not improve from 0.05050
# Epoch 38/100
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0325 - accuracy: 0.9962 - val_loss: 0.0768 - val_accuracy: 0.9852
#
# Epoch 00038: val_loss did not improve from 0.05050
# Epoch 39/100
# 469/469 [==============================] - 21s 44ms/step - loss: 0.0325 - accuracy: 0.9966 - val_loss: 0.0569 - val_accuracy: 0.9904
#
# Epoch 00039: val_loss did not improve from 0.05050
# Epoch 40/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0334 - accuracy: 0.9963 - val_loss: 0.0718 - val_accuracy: 0.9878
#
# Epoch 00040: val_loss did not improve from 0.05050
# Epoch 41/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0312 - accuracy: 0.9968 - val_loss: 0.1182 - val_accuracy: 0.9731
#
# Epoch 00041: val_loss did not improve from 0.05050
# Epoch 42/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0314 - accuracy: 0.9968 - val_loss: 0.0655 - val_accuracy: 0.9867
#
# Epoch 00042: val_loss did not improve from 0.05050
# Epoch 43/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0312 - accuracy: 0.9968 - val_loss: 0.0624 - val_accuracy: 0.9887
#
# Epoch 00043: val_loss did not improve from 0.05050
# Epoch 44/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0306 - accuracy: 0.9970 - val_loss: 0.0694 - val_accuracy: 0.9872
#
# Epoch 00044: val_loss did not improve from 0.05050
# Epoch 45/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0299 - accuracy: 0.9971 - val_loss: 0.1006 - val_accuracy: 0.9784
#
# Epoch 00045: val_loss did not improve from 0.05050
# Epoch 46/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0298 - accuracy: 0.9970 - val_loss: 0.0492 - val_accuracy: 0.9921
#
# Epoch 00046: val_loss improved from 0.05050 to 0.04923, saving model to resnet_v1_MNIST_big.h5
# Epoch 47/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0300 - accuracy: 0.9970 - val_loss: 0.0471 - val_accuracy: 0.9908
#
# Epoch 00047: val_loss improved from 0.04923 to 0.04708, saving model to resnet_v1_MNIST_big.h5
# Epoch 48/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0289 - accuracy: 0.9970 - val_loss: 0.0801 - val_accuracy: 0.9855
#
# Epoch 00048: val_loss did not improve from 0.04708
# Epoch 49/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0294 - accuracy: 0.9968 - val_loss: 0.0460 - val_accuracy: 0.9926
#
# Epoch 00049: val_loss improved from 0.04708 to 0.04604, saving model to resnet_v1_MNIST_big.h5
# Epoch 50/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0288 - accuracy: 0.9969 - val_loss: 0.0790 - val_accuracy: 0.9837
#
# Epoch 00050: val_loss did not improve from 0.04604
# Epoch 51/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0284 - accuracy: 0.9971 - val_loss: 0.0854 - val_accuracy: 0.9844
#
# Epoch 00051: val_loss did not improve from 0.04604
# Epoch 52/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0293 - accuracy: 0.9968 - val_loss: 0.0636 - val_accuracy: 0.9895
#
# Epoch 00052: val_loss did not improve from 0.04604
# Epoch 53/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0285 - accuracy: 0.9968 - val_loss: 0.1455 - val_accuracy: 0.9765
#
# Epoch 00053: val_loss did not improve from 0.04604
# Epoch 54/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0279 - accuracy: 0.9973 - val_loss: 0.0547 - val_accuracy: 0.9904
#
# Epoch 00054: val_loss did not improve from 0.04604
# Epoch 55/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0280 - accuracy: 0.9970 - val_loss: 0.0632 - val_accuracy: 0.9890
#
# Epoch 00055: val_loss did not improve from 0.04604
# Epoch 56/100
# 469/469 [==============================] - 50s 106ms/step - loss: 0.0278 - accuracy: 0.9971 - val_loss: 0.0624 - val_accuracy: 0.9888
#
# Epoch 00056: val_loss did not improve from 0.04604
# Epoch 57/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0272 - accuracy: 0.9973 - val_loss: 0.0665 - val_accuracy: 0.9882
#
# Epoch 00057: val_loss did not improve from 0.04604
# Epoch 58/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0274 - accuracy: 0.9971 - val_loss: 0.0528 - val_accuracy: 0.9912
#
# Epoch 00058: val_loss did not improve from 0.04604
# Epoch 59/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0277 - accuracy: 0.9971 - val_loss: 0.0741 - val_accuracy: 0.9859
#
# Epoch 00059: val_loss did not improve from 0.04604
# Epoch 60/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0272 - accuracy: 0.9974 - val_loss: 0.0532 - val_accuracy: 0.9916
#
# Epoch 00060: val_loss did not improve from 0.04604
# Epoch 61/100
# 469/469 [==============================] - 19s 41ms/step - loss: 0.0262 - accuracy: 0.9974 - val_loss: 0.0708 - val_accuracy: 0.9866
#
# Epoch 00061: val_loss did not improve from 0.04604
# Epoch 62/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0276 - accuracy: 0.9969 - val_loss: 0.0760 - val_accuracy: 0.9861
#
# Epoch 00062: val_loss did not improve from 0.04604
# Epoch 63/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0253 - accuracy: 0.9975 - val_loss: 0.0756 - val_accuracy: 0.9883
#
# Epoch 00063: val_loss did not improve from 0.04604
# Epoch 64/100
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0261 - accuracy: 0.9974 - val_loss: 0.0568 - val_accuracy: 0.9902
#
# Epoch 00064: val_loss did not improve from 0.04604
# Epoch 65/100
# 469/469 [==============================] - 19s 40ms/step - loss: 0.0255 - accuracy: 0.9974 - val_loss: 0.0558 - val_accuracy: 0.9904
#
# Epoch 00065: val_loss did not improve from 0.04604
# Epoch 66/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0262 - accuracy: 0.9972 - val_loss: 0.0564 - val_accuracy: 0.9903
#
# Epoch 00066: val_loss did not improve from 0.04604
# Epoch 67/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0262 - accuracy: 0.9970 - val_loss: 0.0508 - val_accuracy: 0.9924
#
# Epoch 00067: val_loss did not improve from 0.04604
# Epoch 68/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0249 - accuracy: 0.9973 - val_loss: 0.0521 - val_accuracy: 0.9905
#
# Epoch 00068: val_loss did not improve from 0.04604
# Epoch 69/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0245 - accuracy: 0.9977 - val_loss: 0.0721 - val_accuracy: 0.9853
#
# Epoch 00069: val_loss did not improve from 0.04604
# Epoch 70/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0257 - accuracy: 0.9974 - val_loss: 0.0636 - val_accuracy: 0.9877
#
# Epoch 00070: val_loss did not improve from 0.04604
# Epoch 71/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0244 - accuracy: 0.9976 - val_loss: 0.0610 - val_accuracy: 0.9907
#
# Epoch 00071: val_loss did not improve from 0.04604
# Epoch 72/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0248 - accuracy: 0.9973 - val_loss: 0.0776 - val_accuracy: 0.9866
#
# Epoch 00072: val_loss did not improve from 0.04604
# Epoch 73/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0249 - accuracy: 0.9973 - val_loss: 0.0532 - val_accuracy: 0.9908
#
# Epoch 00073: val_loss did not improve from 0.04604
# Epoch 74/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0251 - accuracy: 0.9975 - val_loss: 0.0461 - val_accuracy: 0.9922
#
# Epoch 00074: val_loss did not improve from 0.04604
# Epoch 75/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0252 - accuracy: 0.9974 - val_loss: 0.0624 - val_accuracy: 0.9892
#
# Epoch 00075: val_loss did not improve from 0.04604
# Epoch 76/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0255 - accuracy: 0.9971 - val_loss: 0.0617 - val_accuracy: 0.9879
#
# Epoch 00076: val_loss did not improve from 0.04604
# Epoch 77/100
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0235 - accuracy: 0.9980 - val_loss: 0.0676 - val_accuracy: 0.9875
#
# Epoch 00077: val_loss did not improve from 0.04604
# Epoch 78/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0240 - accuracy: 0.9977 - val_loss: 0.0623 - val_accuracy: 0.9892
#
# Epoch 00078: val_loss did not improve from 0.04604
# Epoch 79/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0243 - accuracy: 0.9975 - val_loss: 0.0508 - val_accuracy: 0.9913
#
# Epoch 00079: val_loss did not improve from 0.04604
# Epoch 80/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0246 - accuracy: 0.9974 - val_loss: 0.0680 - val_accuracy: 0.9889
#
# Epoch 00080: val_loss did not improve from 0.04604
# Epoch 81/100
# 469/469 [==============================] - 20s 42ms/step - loss: 0.0245 - accuracy: 0.9974 - val_loss: 0.0591 - val_accuracy: 0.9894
#
# Epoch 00081: val_loss did not improve from 0.04604
# Epoch 82/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0248 - accuracy: 0.9973 - val_loss: 0.0514 - val_accuracy: 0.9914
#
# Epoch 00082: val_loss did not improve from 0.04604
# Epoch 83/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0239 - accuracy: 0.9974 - val_loss: 0.1228 - val_accuracy: 0.9758
#
# Epoch 00083: val_loss did not improve from 0.04604
# Epoch 84/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0239 - accuracy: 0.9976 - val_loss: 0.0582 - val_accuracy: 0.9902
#
# Epoch 00084: val_loss did not improve from 0.04604
# Epoch 85/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0240 - accuracy: 0.9976 - val_loss: 0.1014 - val_accuracy: 0.9811
#
# Epoch 00085: val_loss did not improve from 0.04604
# Epoch 86/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0240 - accuracy: 0.9975 - val_loss: 0.0579 - val_accuracy: 0.9921
#
# Epoch 00086: val_loss did not improve from 0.04604
# Epoch 87/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0245 - accuracy: 0.9973 - val_loss: 0.0622 - val_accuracy: 0.9901
#
# Epoch 00087: val_loss did not improve from 0.04604
# Epoch 88/100
# 469/469 [==============================] - 18s 37ms/step - loss: 0.0233 - accuracy: 0.9978 - val_loss: 0.0813 - val_accuracy: 0.9876
#
# Epoch 00088: val_loss did not improve from 0.04604
# Epoch 89/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0231 - accuracy: 0.9978 - val_loss: 0.0747 - val_accuracy: 0.9858
#
# Epoch 00089: val_loss did not improve from 0.04604
# Epoch 90/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0242 - accuracy: 0.9973 - val_loss: 0.0794 - val_accuracy: 0.9865
#
# Epoch 00090: val_loss did not improve from 0.04604
# Epoch 91/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0244 - accuracy: 0.9977 - val_loss: 0.1022 - val_accuracy: 0.9798
#
# Epoch 00091: val_loss did not improve from 0.04604
# Epoch 92/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0239 - accuracy: 0.9974 - val_loss: 0.0602 - val_accuracy: 0.9903
#
# Epoch 00092: val_loss did not improve from 0.04604
# Epoch 93/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0230 - accuracy: 0.9977 - val_loss: 0.0833 - val_accuracy: 0.9872
#
# Epoch 00093: val_loss did not improve from 0.04604
# Epoch 94/100
# 469/469 [==============================] - 18s 39ms/step - loss: 0.0235 - accuracy: 0.9976 - val_loss: 0.1109 - val_accuracy: 0.9774
#
# Epoch 00094: val_loss did not improve from 0.04604
# Epoch 95/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0247 - accuracy: 0.9973 - val_loss: 0.0595 - val_accuracy: 0.9892
#
# Epoch 00095: val_loss did not improve from 0.04604
# Epoch 96/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0246 - accuracy: 0.9973 - val_loss: 0.1004 - val_accuracy: 0.9826
#
# Epoch 00096: val_loss did not improve from 0.04604
# Epoch 97/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0234 - accuracy: 0.9976 - val_loss: 0.1093 - val_accuracy: 0.9813
#
# Epoch 00097: val_loss did not improve from 0.04604
# Epoch 98/100
# 469/469 [==============================] - 17s 37ms/step - loss: 0.0228 - accuracy: 0.9977 - val_loss: 0.0594 - val_accuracy: 0.9887
#
# Epoch 00098: val_loss did not improve from 0.04604
# Epoch 99/100
# 469/469 [==============================] - 17s 36ms/step - loss: 0.0226 - accuracy: 0.9979 - val_loss: 0.0824 - val_accuracy: 0.9876
#
# Epoch 00099: val_loss did not improve from 0.04604
# Epoch 100/100
# 469/469 [==============================] - 18s 38ms/step - loss: 0.0235 - accuracy: 0.9975 - val_loss: 0.0814 - val_accuracy: 0.9863
#
# Epoch 00100: val_loss did not improve from 0.04604
